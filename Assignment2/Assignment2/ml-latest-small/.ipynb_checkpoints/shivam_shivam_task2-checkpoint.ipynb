# %%
from collections import Counter
import math
import os
import numpy as np
import pandas as pd
from scipy.sparse import csr_matrix
import sys
import pdb
import scipy
import itertools
import math

# %%
movies_filename = "movies.csv"
rating_train_filename = "ratings_train.csv"
rating_test_filename = "ratings_test.csv"
rating_test_truth_filename = "ratings_test_truth.csv"

# %%
ratings_train = pd.read_csv(rating_train_filename)
ratings_test = pd.read_csv(rating_test_filename)
ratings_test_truth = pd.read_csv(rating_test_truth_filename)
movies = pd.read_csv(movies_filename)

# %%
def get_shingle_hash(hash_size, filename):
    shingles = []
    movieDict = {}
    movieDictInv = {}
    
    with open(filename, 'r') as f:
        next(f)
        i = 0
        for line in f:
            if line[-1] == '\n':
                line = line[0:-1]
                print(line)
            lineRead = [t for t in line[:-1].split(',') if  t != '']
            print(lineRead)
            tokens = [g for g in lineRead[-1].split('|') if g != '']
            print(tokens)
            movieDict[int(lineRead[0])] = i
            print(movieDict)
            movieDictInv[i] = int(lineRead[0])
            print(movieDictInv)
            shingle = set()
            for ngram in tokens:
                ngram = frozenset(ngram)
                ngram_hash = hash(ngram) % hash_size
                shingle.add(ngram_hash)
            print(shingle)
            shingles.append(shingle)
            i += 1
        
        # return None to keep the same signature as q1
    return shingles, movieDict, movieDictInv

# %%
def get_hash_coeffs(br):
    rnds = np.random.choice(2**10, (2, br), replace=False)
    c = 1048583
    return rnds[0], rnds[1], c

# %%
def min_hashing(shingles, hash_coeffs, br):
    count = len(shingles)
    (a, b, c) = hash_coeffs
    a = a.reshape(1, -1)
    M = np.zeros((br, count), dtype=int) 
    for i, s in enumerate(shingles):
        
        row_idx = np.asarray(list(s)).reshape(-1, 1)
        m = (np.matmul(row_idx, a) + b) % c
        m_min = np.min(m, axis=0) 
        M[:, i] = m_min

    return M

# %%
def LSH(M, b, r, band_hash_size):
    count = M.shape[1]
    bucket_list = []
    for band_index in range(b):
        # The hash table for each band is stored as a sparse matrix! Learn basics about sparse matrix here: https://docs.scipy.org/doc/scipy/reference/sparse.html
        # However, I did a few benchmark, lil_matrix, dok_matrix are claimed to be efficient for incremental consturction, they are not as efficient as store indices of non-zero entries in a list
        # So instead of having a matrix, just two arrays to store the indices
        # But we need to image there is a matrix. Its layout same as slide 56. Cols are documents, rows are hash of signature index
        row_idx = []
        col_idx = []

        row_start = band_index * r
        for c in range(count):
            v = M[row_start:(row_start+r), c]
            v_hash = hash(tuple(v.tolist())) % band_hash_size
            row_idx.append(v_hash)
            col_idx.append(c)

        # It's a binary matrix. Set to True at these indices.
        data_ary = [True] * len(row_idx)

        # Convert to row based sparse matrix for fast processing later
        m = scipy.sparse.csr_matrix((data_ary, (row_idx, col_idx)), shape=(band_hash_size, count), dtype=bool)
        bucket_list.append(m)

    return bucket_list

# %%
def find_similiar(shingles, query_index, threshold, bucket_list, M, b, r, band_hash_size, verify_by_signature, movieDictInv):
    # Step 1: Find candidates
    candidates = set()
    for band_index in range(b):
        row_start = band_index * r
        v = M[row_start:(row_start+r), query_index]
        v_hash = hash(tuple(v.tolist())) % band_hash_size

        m = bucket_list[band_index]
        bucket = m[v_hash].indices #Sparse sparse matrix method: get indices of nonzero elements
        #print(f'Band: {band_index}, candidates: {bucket}')
        candidates = candidates.union(bucket)

   # print(f'Found {len(candidates)} candidates')

    # Step 2: Verify similarity of candidates
    sims = {}
    simsSet = set()
    # Since the candidates size is small, we just evaluate it on k-shingles matrix, or signature matrix for greater efficiency
    if verify_by_signature:
        query_vec = M[:, query_index]
        for col_idx in candidates:
            col = M[:, col_idx]
            sim = np.mean(col == query_vec) # Jaccard Similarity is proportional to the fraction of the minhashing signature they agree
            if sim >= threshold:
                sims[movieDictInv[col_idx]] = sim
                simsSet.add(movieDictInv[col_idx])
                
    else:
        query_set = shingles[query_index]
        for col_idx in candidates:
            col_set = shingles[col_idx]

            sim = len(query_set & col_set) / len(query_set | col_set) # Jaccard Similarity
            if sim >= threshold:
                sims[movieDictInv[col_idx]] = sim
                simsSet.add(movieDictInv[col_idx])

    return sims, simsSet

# %%
threshold = 0.8
hash_size = 2**20
band_hash_size = 2**8
verify_by_signature = False

b = 7
r = 2
br = b*r

# %%
shingles, movieDict, movieDictInv  = get_shingle_hash(hash_size, movies_filename)
hash_coeffs = get_hash_coeffs(br)
M = min_hashing(shingles, hash_coeffs, br)
bucket_list = LSH(M, b, r, band_hash_size)
# Out:
# 1,Toy Story (1995),Adventure|Animation|Children|Comedy|Fantasy
# ['1', 'Toy Story (1995)', 'Adventure|Animation|Children|Comedy|Fantas']
# 2,Jumanji (1995),Adventure|Children|Fantasy
# ['2', 'Jumanji (1995)', 'Adventure|Children|Fantas']
# 3,Grumpier Old Men (1995),Comedy|Romance
# ['3', 'Grumpier Old Men (1995)', 'Comedy|Romanc']
# 4,Waiting to Exhale (1995),Comedy|Drama|Romance
# ['4', 'Waiting to Exhale (1995)', 'Comedy|Drama|Romanc']
# 5,Father of the Bride Part II (1995),Comedy
# ['5', 'Father of the Bride Part II (1995)', 'Comed']
# 6,Heat (1995),Action|Crime|Thriller
# ['6', 'Heat (1995)', 'Action|Crime|Thrille']
# 7,Sabrina (1995),Comedy|Romance
# ['7', 'Sabrina (1995)', 'Comedy|Romanc']
# 8,Tom and Huck (1995),Adventure|Children
# ['8', 'Tom and Huck (1995)', 'Adventure|Childre']
# 9,Sudden Death (1995),Action
# ['9', 'Sudden Death (1995)', 'Actio']
# 10,GoldenEye (1995),Action|Adventure|Thriller
# ['10', 'GoldenEye (1995)', 'Action|Adventure|Thrille']
# 11,"American President, The (1995)",Comedy|Drama|Romance
# ['11', '"American President', ' The (1995)"', 'Comedy|Drama|Romanc']
# 12,Dracula: Dead and Loving It (1995),Comedy|Horror
# ['12', 'Dracula: Dead and Loving It (1995)', 'Comedy|Horro']
# 13,Balto (1995),Adventure|Animation|Children
# ['13', 'Balto (1995)', 'Adventure|Animation|Childre']
# 14,Nixon (1995),Drama
# ['14', 'Nixon (1995)', 'Dram']
# 15,Cutthroat Island (1995),Action|Adventure|Romance
# ['15', 'Cutthroat Island (1995)', 'Action|Adventure|Romanc']
# 16,Casino (1995),Crime|Drama
# ['16', 'Casino (1995)', 'Crime|Dram']
# 17,Sense and Sensibility (1995),Drama|Romance
# ['17', 'Sense and Sensibility (1995)', 'Drama|Romanc']
# 18,Four Rooms (1995),Comedy
# ['18', 'Four Rooms (1995)', 'Comed']
# 19,Ace Ventura: When Nature Calls (1995),Comedy
# ['19', 'Ace Ventura: When Nature Calls (1995)', 'Comed']
# 20,Money Train (1995),Action|Comedy|Crime|Drama|Thriller
# ['20', 'Money Train (1995)', 'Action|Comedy|Crime|Drama|Thrille']
# 21,Get Shorty (1995),Comedy|Crime|Thriller
# ['21', 'Get Shorty (1995)', 'Comedy|Crime|Thrille']
# 22,Copycat (1995),Crime|Drama|Horror|Mystery|Thriller
# ['22', 'Copycat (1995)', 'Crime|Drama|Horror|Mystery|Thrille']
# 23,Assassins (1995),Action|Crime|Thriller
# ['23', 'Assassins (1995)', 'Action|Crime|Thrille']
# 24,Powder (1995),Drama|Sci-Fi
# ['24', 'Powder (1995)', 'Drama|Sci-F']
# 25,Leaving Las Vegas (1995),Drama|Romance
# ['25', 'Leaving Las Vegas (1995)', 'Drama|Romanc']
# 26,Othello (1995),Drama
# ['26', 'Othello (1995)', 'Dram']
# 27,Now and Then (1995),Children|Drama
# ['27', 'Now and Then (1995)', 'Children|Dram']
# 28,Persuasion (1995),Drama|Romance
# ['28', 'Persuasion (1995)', 'Drama|Romanc']
# 29,"City of Lost Children, The (CitÃ© des enfants perdus, La) (1995)",Adventure|Drama|Fantasy|Mystery|Sci-Fi
# ['29', '"City of Lost Children', ' The (CitÃ© des enfants perdus', ' La) (1995)"', 'Adventure|Drama|Fantasy|Mystery|Sci-F']
# 30,Shanghai Triad (Yao a yao yao dao waipo qiao) (1995),Crime|Drama
# ['30', 'Shanghai Triad (Yao a yao yao dao waipo qiao) (1995)', 'Crime|Dram']
# 31,Dangerous Minds (1995),Drama
# ['31', 'Dangerous Minds (1995)', 'Dram']
# 32,Twelve Monkeys (a.k.a. 12 Monkeys) (1995),Mystery|Sci-Fi|Thriller
# ['32', 'Twelve Monkeys (a.k.a. 12 Monkeys) (1995)', 'Mystery|Sci-Fi|Thrille']
# 34,Babe (1995),Children|Drama
# ['34', 'Babe (1995)', 'Children|Dram']
# 36,Dead Man Walking (1995),Crime|Drama
# ['36', 'Dead Man Walking (1995)', 'Crime|Dram']
# 38,It Takes Two (1995),Children|Comedy
# ['38', 'It Takes Two (1995)', 'Children|Comed']
# 39,Clueless (1995),Comedy|Romance
# ['39', 'Clueless (1995)', 'Comedy|Romanc']
# 40,"Cry, the Beloved Country (1995)",Drama
# ['40', '"Cry', ' the Beloved Country (1995)"', 'Dram']
# 41,Richard III (1995),Drama|War
# ['41', 'Richard III (1995)', 'Drama|Wa']
# 42,Dead Presidents (1995),Action|Crime|Drama
# ['42', 'Dead Presidents (1995)', 'Action|Crime|Dram']
# 43,Restoration (1995),Drama
# ['43', 'Restoration (1995)', 'Dram']
# 44,Mortal Kombat (1995),Action|Adventure|Fantasy
# ['44', 'Mortal Kombat (1995)', 'Action|Adventure|Fantas']
# 45,To Die For (1995),Comedy|Drama|Thriller
# ['45', 'To Die For (1995)', 'Comedy|Drama|Thrille']
# 46,How to Make an American Quilt (1995),Drama|Romance
# ['46', 'How to Make an American Quilt (1995)', 'Drama|Romanc']
# 47,Seven (a.k.a. Se7en) (1995),Mystery|Thriller
# ['47', 'Seven (a.k.a. Se7en) (1995)', 'Mystery|Thrille']
# 48,Pocahontas (1995),Animation|Children|Drama|Musical|Romance
# ['48', 'Pocahontas (1995)', 'Animation|Children|Drama|Musical|Romanc']
# 49,When Night Is Falling (1995),Drama|Romance
# ['49', 'When Night Is Falling (1995)', 'Drama|Romanc']
# 50,"Usual Suspects, The (1995)",Crime|Mystery|Thriller
# ['50', '"Usual Suspects', ' The (1995)"', 'Crime|Mystery|Thrille']
# 52,Mighty Aphrodite (1995),Comedy|Drama|Romance
# ['52', 'Mighty Aphrodite (1995)', 'Comedy|Drama|Romanc']
# 53,Lamerica (1994),Adventure|Drama
# ['53', 'Lamerica (1994)', 'Adventure|Dram']
# 54,"Big Green, The (1995)",Children|Comedy
# ['54', '"Big Green', ' The (1995)"', 'Children|Comed']
# 55,Georgia (1995),Drama
# ['55', 'Georgia (1995)', 'Dram']
# 57,Home for the Holidays (1995),Drama
# ['57', 'Home for the Holidays (1995)', 'Dram']
# 58,"Postman, The (Postino, Il) (1994)",Comedy|Drama|Romance
# ['58', '"Postman', ' The (Postino', ' Il) (1994)"', 'Comedy|Drama|Romanc']
# 60,"Indian in the Cupboard, The (1995)",Adventure|Children|Fantasy
# ['60', '"Indian in the Cupboard', ' The (1995)"', 'Adventure|Children|Fantas']
# 61,Eye for an Eye (1996),Drama|Thriller
# ['61', 'Eye for an Eye (1996)', 'Drama|Thrille']
# 62,Mr. Holland's Opus (1995),Drama
# ['62', "Mr. Holland's Opus (1995)", 'Dram']
# 63,Don't Be a Menace to South Central While Drinking Your Juice in the Hood (1996),Comedy|Crime
# ['63', "Don't Be a Menace to South Central While Drinking Your Juice in the Hood (1996)", 'Comedy|Crim']
# 64,Two if by Sea (1996),Comedy|Romance
# ['64', 'Two if by Sea (1996)', 'Comedy|Romanc']
# 65,Bio-Dome (1996),Comedy
# ['65', 'Bio-Dome (1996)', 'Comed']
# 66,Lawnmower Man 2: Beyond Cyberspace (1996),Action|Sci-Fi|Thriller
# ['66', 'Lawnmower Man 2: Beyond Cyberspace (1996)', 'Action|Sci-Fi|Thrille']
# 68,French Twist (Gazon maudit) (1995),Comedy|Romance
# ['68', 'French Twist (Gazon maudit) (1995)', 'Comedy|Romanc']
# 69,Friday (1995),Comedy
# ['69', 'Friday (1995)', 'Comed']
# 70,From Dusk Till Dawn (1996),Action|Comedy|Horror|Thriller
# ['70', 'From Dusk Till Dawn (1996)', 'Action|Comedy|Horror|Thrille']
# 71,Fair Game (1995),Action
# ['71', 'Fair Game (1995)', 'Actio']
# 72,Kicking and Screaming (1995),Comedy|Drama
# ['72', 'Kicking and Screaming (1995)', 'Comedy|Dram']
# 73,"MisÃ©rables, Les (1995)",Drama|War
# ['73', '"MisÃ©rables', ' Les (1995)"', 'Drama|Wa']
# 74,Bed of Roses (1996),Drama|Romance
# ['74', 'Bed of Roses (1996)', 'Drama|Romanc']
# 75,Big Bully (1996),Comedy|Drama
# ['75', 'Big Bully (1996)', 'Comedy|Dram']
# 76,Screamers (1995),Action|Sci-Fi|Thriller
# ['76', 'Screamers (1995)', 'Action|Sci-Fi|Thrille']
# 77,Nico Icon (1995),Documentary
# ['77', 'Nico Icon (1995)', 'Documentar']
# 78,"Crossing Guard, The (1995)",Action|Crime|Drama|Thriller
# ['78', '"Crossing Guard', ' The (1995)"', 'Action|Crime|Drama|Thrille']
# 79,"Juror, The (1996)",Drama|Thriller
# ['79', '"Juror', ' The (1996)"', 'Drama|Thrille']
# 80,"White Balloon, The (Badkonake sefid) (1995)",Children|Drama
# ['80', '"White Balloon', ' The (Badkonake sefid) (1995)"', 'Children|Dram']
# 81,Things to Do in Denver When You're Dead (1995),Crime|Drama|Romance
# ['81', "Things to Do in Denver When You're Dead (1995)", 'Crime|Drama|Romanc']
# 82,Antonia's Line (Antonia) (1995),Comedy|Drama
# ['82', "Antonia's Line (Antonia) (1995)", 'Comedy|Dram']
# 83,Once Upon a Time... When We Were Colored (1995),Drama|Romance
# ['83', 'Once Upon a Time... When We Were Colored (1995)', 'Drama|Romanc']
# 85,Angels and Insects (1995),Drama|Romance
# ['85', 'Angels and Insects (1995)', 'Drama|Romanc']
# 86,White Squall (1996),Action|Adventure|Drama
# ['86', 'White Squall (1996)', 'Action|Adventure|Dram']
# 87,Dunston Checks In (1996),Children|Comedy
# ['87', 'Dunston Checks In (1996)', 'Children|Comed']
# 88,Black Sheep (1996),Comedy
# ['88', 'Black Sheep (1996)', 'Comed']
# 89,Nick of Time (1995),Action|Thriller
# ['89', 'Nick of Time (1995)', 'Action|Thrille']
# 92,Mary Reilly (1996),Drama|Horror|Thriller
# ['92', 'Mary Reilly (1996)', 'Drama|Horror|Thrille']
# 93,Vampire in Brooklyn (1995),Comedy|Horror|Romance
# ['93', 'Vampire in Brooklyn (1995)', 'Comedy|Horror|Romanc']
# 94,Beautiful Girls (1996),Comedy|Drama|Romance
# ['94', 'Beautiful Girls (1996)', 'Comedy|Drama|Romanc']
# 95,Broken Arrow (1996),Action|Adventure|Thriller
# ['95', 'Broken Arrow (1996)', 'Action|Adventure|Thrille']
# 96,In the Bleak Midwinter (1995),Comedy|Drama
# ['96', 'In the Bleak Midwinter (1995)', 'Comedy|Dram']
# 97,"Hate (Haine, La) (1995)",Crime|Drama
# ['97', '"Hate (Haine', ' La) (1995)"', 'Crime|Dram']
# 99,Heidi Fleiss: Hollywood Madam (1995),Documentary
# ['99', 'Heidi Fleiss: Hollywood Madam (1995)', 'Documentar']
# 100,City Hall (1996),Drama|Thriller
# ['100', 'City Hall (1996)', 'Drama|Thrille']
# 101,Bottle Rocket (1996),Adventure|Comedy|Crime|Romance
# ['101', 'Bottle Rocket (1996)', 'Adventure|Comedy|Crime|Romanc']
# 102,Mr. Wrong (1996),Comedy
# ['102', 'Mr. Wrong (1996)', 'Comed']
# 103,Unforgettable (1996),Mystery|Sci-Fi|Thriller
# ['103', 'Unforgettable (1996)', 'Mystery|Sci-Fi|Thrille']
# 104,Happy Gilmore (1996),Comedy
# ['104', 'Happy Gilmore (1996)', 'Comed']
# 105,"Bridges of Madison County, The (1995)",Drama|Romance
# ['105', '"Bridges of Madison County', ' The (1995)"', 'Drama|Romanc']
# 106,Nobody Loves Me (Keiner liebt mich) (1994),Comedy|Drama
# ['106', 'Nobody Loves Me (Keiner liebt mich) (1994)', 'Comedy|Dram']
# 107,Muppet Treasure Island (1996),Adventure|Children|Comedy|Musical
# ['107', 'Muppet Treasure Island (1996)', 'Adventure|Children|Comedy|Musica']
# 108,Catwalk (1996),Documentary
# ['108', 'Catwalk (1996)', 'Documentar']
# 110,Braveheart (1995),Action|Drama|War
# ['110', 'Braveheart (1995)', 'Action|Drama|Wa']
# 111,Taxi Driver (1976),Crime|Drama|Thriller
# ['111', 'Taxi Driver (1976)', 'Crime|Drama|Thrille']
# 112,Rumble in the Bronx (Hont faan kui) (1995),Action|Adventure|Comedy|Crime
# ['112', 'Rumble in the Bronx (Hont faan kui) (1995)', 'Action|Adventure|Comedy|Crim']
# 113,Before and After (1996),Drama|Mystery
# ['113', 'Before and After (1996)', 'Drama|Myster']
# 116,Anne Frank Remembered (1995),Documentary
# ['116', 'Anne Frank Remembered (1995)', 'Documentar']
# 117,"Young Poisoner's Handbook, The (1995)",Crime|Drama
# ['117', '"Young Poisoner\'s Handbook', ' The (1995)"', 'Crime|Dram']
# 118,If Lucy Fell (1996),Comedy|Romance
# ['118', 'If Lucy Fell (1996)', 'Comedy|Romanc']
# 119,"Steal Big, Steal Little (1995)",Comedy
# ['119', '"Steal Big', ' Steal Little (1995)"', 'Comed']
# 121,"Boys of St. Vincent, The (1992)",Drama
# ['121', '"Boys of St. Vincent', ' The (1992)"', 'Dram']
# 122,Boomerang (1992),Comedy|Romance
# ['122', 'Boomerang (1992)', 'Comedy|Romanc']
# 123,Chungking Express (Chung Hing sam lam) (1994),Drama|Mystery|Romance
# ['123', 'Chungking Express (Chung Hing sam lam) (1994)', 'Drama|Mystery|Romanc']
# 125,Flirting With Disaster (1996),Comedy
# ['125', 'Flirting With Disaster (1996)', 'Comed']
# 126,"NeverEnding Story III, The (1994)",Adventure|Children|Fantasy
# ['126', '"NeverEnding Story III', ' The (1994)"', 'Adventure|Children|Fantas']
# 128,Jupiter's Wife (1994),Documentary
# ['128', "Jupiter's Wife (1994)", 'Documentar']
# 129,Pie in the Sky (1996),Comedy|Romance
# ['129', 'Pie in the Sky (1996)', 'Comedy|Romanc']
# 132,Jade (1995),Thriller
# ['132', 'Jade (1995)', 'Thrille']
# 135,Down Periscope (1996),Comedy
# ['135', 'Down Periscope (1996)', 'Comed']
# 137,Man of the Year (1995),Documentary
# ['137', 'Man of the Year (1995)', 'Documentar']
# 140,Up Close and Personal (1996),Drama|Romance
# ['140', 'Up Close and Personal (1996)', 'Drama|Romanc']
# 141,"Birdcage, The (1996)",Comedy
# ['141', '"Birdcage', ' The (1996)"', 'Comed']
# 144,"Brothers McMullen, The (1995)",Comedy
# ['144', '"Brothers McMullen', ' The (1995)"', 'Comed']
# 145,Bad Boys (1995),Action|Comedy|Crime|Drama|Thriller
# ['145', 'Bad Boys (1995)', 'Action|Comedy|Crime|Drama|Thrille']
# 146,"Amazing Panda Adventure, The (1995)",Adventure|Children
# ['146', '"Amazing Panda Adventure', ' The (1995)"', 'Adventure|Childre']
# 147,"Basketball Diaries, The (1995)",Drama
# ['147', '"Basketball Diaries', ' The (1995)"', 'Dram']
# 148,"Awfully Big Adventure, An (1995)",Drama
# ['148', '"Awfully Big Adventure', ' An (1995)"', 'Dram']
# 149,Amateur (1994),Crime|Drama|Thriller
# ['149', 'Amateur (1994)', 'Crime|Drama|Thrille']
# 150,Apollo 13 (1995),Adventure|Drama|IMAX
# ['150', 'Apollo 13 (1995)', 'Adventure|Drama|IMA']
# 151,Rob Roy (1995),Action|Drama|Romance|War
# ['151', 'Rob Roy (1995)', 'Action|Drama|Romance|Wa']
# 152,"Addiction, The (1995)",Drama|Horror
# ['152', '"Addiction', ' The (1995)"', 'Drama|Horro']
# 153,Batman Forever (1995),Action|Adventure|Comedy|Crime
# ['153', 'Batman Forever (1995)', 'Action|Adventure|Comedy|Crim']
# 154,Beauty of the Day (Belle de jour) (1967),Drama
# ['154', 'Beauty of the Day (Belle de jour) (1967)', 'Dram']
# 155,Beyond Rangoon (1995),Adventure|Drama|War
# ['155', 'Beyond Rangoon (1995)', 'Adventure|Drama|Wa']
# 156,Blue in the Face (1995),Comedy|Drama
# ['156', 'Blue in the Face (1995)', 'Comedy|Dram']
# 157,Canadian Bacon (1995),Comedy|War
# ['157', 'Canadian Bacon (1995)', 'Comedy|Wa']
# 158,Casper (1995),Adventure|Children
# ['158', 'Casper (1995)', 'Adventure|Childre']
# 159,Clockers (1995),Crime|Drama|Mystery
# ['159', 'Clockers (1995)', 'Crime|Drama|Myster']
# 160,Congo (1995),Action|Adventure|Mystery|Sci-Fi
# ['160', 'Congo (1995)', 'Action|Adventure|Mystery|Sci-F']
# 161,Crimson Tide (1995),Drama|Thriller|War
# ['161', 'Crimson Tide (1995)', 'Drama|Thriller|Wa']
# 162,Crumb (1994),Documentary
# ['162', 'Crumb (1994)', 'Documentar']
# 163,Desperado (1995),Action|Romance|Western
# ['163', 'Desperado (1995)', 'Action|Romance|Wester']
# 164,Devil in a Blue Dress (1995),Crime|Film-Noir|Mystery|Thriller
# ['164', 'Devil in a Blue Dress (1995)', 'Crime|Film-Noir|Mystery|Thrille']
# 165,Die Hard: With a Vengeance (1995),Action|Crime|Thriller
# ['165', 'Die Hard: With a Vengeance (1995)', 'Action|Crime|Thrille']
# 166,"Doom Generation, The (1995)",Comedy|Crime|Drama
# ['166', '"Doom Generation', ' The (1995)"', 'Comedy|Crime|Dram']
# 168,First Knight (1995),Action|Drama|Romance
# ['168', 'First Knight (1995)', 'Action|Drama|Romanc']
# 169,Free Willy 2: The Adventure Home (1995),Adventure|Children|Drama
# ['169', 'Free Willy 2: The Adventure Home (1995)', 'Adventure|Children|Dram']
# 170,Hackers (1995),Action|Adventure|Crime|Thriller
# ['170', 'Hackers (1995)', 'Action|Adventure|Crime|Thrille']
# 171,Jeffrey (1995),Comedy|Drama
# ['171', 'Jeffrey (1995)', 'Comedy|Dram']
# 172,Johnny Mnemonic (1995),Action|Sci-Fi|Thriller
# ['172', 'Johnny Mnemonic (1995)', 'Action|Sci-Fi|Thrille']
# 173,Judge Dredd (1995),Action|Crime|Sci-Fi
# ['173', 'Judge Dredd (1995)', 'Action|Crime|Sci-F']
# 174,Jury Duty (1995),Comedy
# ['174', 'Jury Duty (1995)', 'Comed']
# 175,Kids (1995),Drama
# ['175', 'Kids (1995)', 'Dram']
# 176,Living in Oblivion (1995),Comedy
# ['176', 'Living in Oblivion (1995)', 'Comed']
# 177,Lord of Illusions (1995),Horror
# ['177', 'Lord of Illusions (1995)', 'Horro']
# 178,Love & Human Remains (1993),Comedy|Drama
# ['178', 'Love & Human Remains (1993)', 'Comedy|Dram']
# 179,Mad Love (1995),Drama|Romance
# ['179', 'Mad Love (1995)', 'Drama|Romanc']
# 180,Mallrats (1995),Comedy|Romance
# ['180', 'Mallrats (1995)', 'Comedy|Romanc']
# 181,Mighty Morphin Power Rangers: The Movie (1995),Action|Children
# ['181', 'Mighty Morphin Power Rangers: The Movie (1995)', 'Action|Childre']
# 183,Mute Witness (1994),Comedy|Horror|Thriller
# ['183', 'Mute Witness (1994)', 'Comedy|Horror|Thrille']
# 184,Nadja (1994),Drama
# ['184', 'Nadja (1994)', 'Dram']
# 185,"Net, The (1995)",Action|Crime|Thriller
# ['185', '"Net', ' The (1995)"', 'Action|Crime|Thrille']
# 186,Nine Months (1995),Comedy|Romance
# ['186', 'Nine Months (1995)', 'Comedy|Romanc']
# 187,Party Girl (1995),Comedy
# ['187', 'Party Girl (1995)', 'Comed']
# 188,"Prophecy, The (1995)",Fantasy|Horror|Mystery
# ['188', '"Prophecy', ' The (1995)"', 'Fantasy|Horror|Myster']
# 189,Reckless (1995),Comedy|Fantasy
# ['189', 'Reckless (1995)', 'Comedy|Fantas']
# 190,Safe (1995),Thriller
# ['190', 'Safe (1995)', 'Thrille']
# 191,"Scarlet Letter, The (1995)",Drama|Romance
# ['191', '"Scarlet Letter', ' The (1995)"', 'Drama|Romanc']
# 193,Showgirls (1995),Drama
# ['193', 'Showgirls (1995)', 'Dram']
# 194,Smoke (1995),Comedy|Drama
# ['194', 'Smoke (1995)', 'Comedy|Dram']
# 195,Something to Talk About (1995),Comedy|Drama|Romance
# ['195', 'Something to Talk About (1995)', 'Comedy|Drama|Romanc']
# 196,Species (1995),Horror|Sci-Fi
# ['196', 'Species (1995)', 'Horror|Sci-F']
# 198,Strange Days (1995),Action|Crime|Drama|Mystery|Sci-Fi|Thriller
# ['198', 'Strange Days (1995)', 'Action|Crime|Drama|Mystery|Sci-Fi|Thrille']
# 199,"Umbrellas of Cherbourg, The (Parapluies de Cherbourg, Les) (1964)",Drama|Musical|Romance
# ['199', '"Umbrellas of Cherbourg', ' The (Parapluies de Cherbourg', ' Les) (1964)"', 'Drama|Musical|Romanc']
# 201,Three Wishes (1995),Drama|Fantasy
# ['201', 'Three Wishes (1995)', 'Drama|Fantas']
# 202,Total Eclipse (1995),Drama|Romance
# ['202', 'Total Eclipse (1995)', 'Drama|Romanc']
# 203,"To Wong Foo, Thanks for Everything! Julie Newmar (1995)",Comedy
# ['203', '"To Wong Foo', ' Thanks for Everything! Julie Newmar (1995)"', 'Comed']
# 204,Under Siege 2: Dark Territory (1995),Action
# ['204', 'Under Siege 2: Dark Territory (1995)', 'Actio']
# 205,Unstrung Heroes (1995),Comedy|Drama
# ['205', 'Unstrung Heroes (1995)', 'Comedy|Dram']
# 206,Unzipped (1995),Documentary
# ['206', 'Unzipped (1995)', 'Documentar']
# 207,"Walk in the Clouds, A (1995)",Drama|Romance
# ['207', '"Walk in the Clouds', ' A (1995)"', 'Drama|Romanc']
# 208,Waterworld (1995),Action|Adventure|Sci-Fi
# ['208', 'Waterworld (1995)', 'Action|Adventure|Sci-F']
# 209,White Man's Burden (1995),Drama
# ['209', "White Man's Burden (1995)", 'Dram']
# 210,Wild Bill (1995),Western
# ['210', 'Wild Bill (1995)', 'Wester']
# 211,"Browning Version, The (1994)",Drama
# ['211', '"Browning Version', ' The (1994)"', 'Dram']
# 212,Bushwhacked (1995),Adventure|Comedy|Crime|Mystery
# ['212', 'Bushwhacked (1995)', 'Adventure|Comedy|Crime|Myster']
# 213,Burnt by the Sun (Utomlyonnye solntsem) (1994),Drama
# ['213', 'Burnt by the Sun (Utomlyonnye solntsem) (1994)', 'Dram']
# 214,Before the Rain (Pred dozhdot) (1994),Drama|War
# ['214', 'Before the Rain (Pred dozhdot) (1994)', 'Drama|Wa']
# 215,Before Sunrise (1995),Drama|Romance
# ['215', 'Before Sunrise (1995)', 'Drama|Romanc']
# 216,Billy Madison (1995),Comedy
# ['216', 'Billy Madison (1995)', 'Comed']
# 217,"Babysitter, The (1995)",Drama|Thriller
# ['217', '"Babysitter', ' The (1995)"', 'Drama|Thrille']
# 218,Boys on the Side (1995),Comedy|Drama
# ['218', 'Boys on the Side (1995)', 'Comedy|Dram']
# 219,"Cure, The (1995)",Drama
# ['219', '"Cure', ' The (1995)"', 'Dram']
# 220,Castle Freak (1995),Horror
# ['220', 'Castle Freak (1995)', 'Horro']
# 222,Circle of Friends (1995),Drama|Romance
# ['222', 'Circle of Friends (1995)', 'Drama|Romanc']
# 223,Clerks (1994),Comedy
# ['223', 'Clerks (1994)', 'Comed']
# 224,Don Juan DeMarco (1995),Comedy|Drama|Romance
# ['224', 'Don Juan DeMarco (1995)', 'Comedy|Drama|Romanc']
# 225,Disclosure (1994),Drama|Thriller
# ['225', 'Disclosure (1994)', 'Drama|Thrille']
# 227,Drop Zone (1994),Action|Thriller
# ['227', 'Drop Zone (1994)', 'Action|Thrille']
# 228,Destiny Turns on the Radio (1995),Comedy
# ['228', 'Destiny Turns on the Radio (1995)', 'Comed']
# 229,Death and the Maiden (1994),Drama|Thriller
# ['229', 'Death and the Maiden (1994)', 'Drama|Thrille']
# 230,Dolores Claiborne (1995),Drama|Thriller
# ['230', 'Dolores Claiborne (1995)', 'Drama|Thrille']
# 231,Dumb & Dumber (Dumb and Dumber) (1994),Adventure|Comedy
# ['231', 'Dumb & Dumber (Dumb and Dumber) (1994)', 'Adventure|Comed']
# 232,Eat Drink Man Woman (Yin shi nan nu) (1994),Comedy|Drama|Romance
# ['232', 'Eat Drink Man Woman (Yin shi nan nu) (1994)', 'Comedy|Drama|Romanc']
# 233,Exotica (1994),Drama
# ['233', 'Exotica (1994)', 'Dram']
# 234,Exit to Eden (1994),Comedy
# ['234', 'Exit to Eden (1994)', 'Comed']
# 235,Ed Wood (1994),Comedy|Drama
# ['235', 'Ed Wood (1994)', 'Comedy|Dram']
# 236,French Kiss (1995),Action|Comedy|Romance
# ['236', 'French Kiss (1995)', 'Action|Comedy|Romanc']
# 237,Forget Paris (1995),Comedy|Romance
# ['237', 'Forget Paris (1995)', 'Comedy|Romanc']
# 238,Far From Home: The Adventures of Yellow Dog (1995),Adventure|Children
# ['238', 'Far From Home: The Adventures of Yellow Dog (1995)', 'Adventure|Childre']
# 239,"Goofy Movie, A (1995)",Animation|Children|Comedy|Romance
# ['239', '"Goofy Movie', ' A (1995)"', 'Animation|Children|Comedy|Romanc']
# 240,Hideaway (1995),Thriller
# ['240', 'Hideaway (1995)', 'Thrille']
# 241,Fluke (1995),Children|Drama
# ['241', 'Fluke (1995)', 'Children|Dram']
# 242,Farinelli: il castrato (1994),Drama|Musical
# ['242', 'Farinelli: il castrato (1994)', 'Drama|Musica']
# 243,Gordy (1995),Children|Comedy|Fantasy
# ['243', 'Gordy (1995)', 'Children|Comedy|Fantas']
# 246,Hoop Dreams (1994),Documentary
# ['246', 'Hoop Dreams (1994)', 'Documentar']
# 247,Heavenly Creatures (1994),Crime|Drama
# ['247', 'Heavenly Creatures (1994)', 'Crime|Dram']
# 248,Houseguest (1994),Comedy
# ['248', 'Houseguest (1994)', 'Comed']
# 249,Immortal Beloved (1994),Drama|Romance
# ['249', 'Immortal Beloved (1994)', 'Drama|Romanc']
# 250,Heavyweights (Heavy Weights) (1995),Children|Comedy
# ['250', 'Heavyweights (Heavy Weights) (1995)', 'Children|Comed']
# 251,"Hunted, The (1995)",Action
# ['251', '"Hunted', ' The (1995)"', 'Actio']
# 252,I.Q. (1994),Comedy|Romance
# ['252', 'I.Q. (1994)', 'Comedy|Romanc']
# 253,Interview with the Vampire: The Vampire Chronicles (1994),Drama|Horror
# ['253', 'Interview with the Vampire: The Vampire Chronicles (1994)', 'Drama|Horro']
# 254,Jefferson in Paris (1995),Drama
# ['254', 'Jefferson in Paris (1995)', 'Dram']
# 255,"Jerky Boys, The (1995)",Comedy
# ['255', '"Jerky Boys', ' The (1995)"', 'Comed']
# 256,Junior (1994),Comedy|Sci-Fi
# ['256', 'Junior (1994)', 'Comedy|Sci-F']
# 257,Just Cause (1995),Mystery|Thriller
# ['257', 'Just Cause (1995)', 'Mystery|Thrille']
# 258,"Kid in King Arthur's Court, A (1995)",Adventure|Children|Comedy|Fantasy|Romance
# ['258', '"Kid in King Arthur\'s Court', ' A (1995)"', 'Adventure|Children|Comedy|Fantasy|Romanc']
# 259,Kiss of Death (1995),Crime|Drama|Thriller
# ['259', 'Kiss of Death (1995)', 'Crime|Drama|Thrille']
# 260,Star Wars: Episode IV - A New Hope (1977),Action|Adventure|Sci-Fi
# ['260', 'Star Wars: Episode IV - A New Hope (1977)', 'Action|Adventure|Sci-F']
# 261,Little Women (1994),Drama
# ['261', 'Little Women (1994)', 'Dram']
# 262,"Little Princess, A (1995)",Children|Drama
# ['262', '"Little Princess', ' A (1995)"', 'Children|Dram']
# 263,Ladybird Ladybird (1994),Drama
# ['263', 'Ladybird Ladybird (1994)', 'Dram']
# 265,Like Water for Chocolate (Como agua para chocolate) (1992),Drama|Fantasy|Romance
# ['265', 'Like Water for Chocolate (Como agua para chocolate) (1992)', 'Drama|Fantasy|Romanc']
# 266,Legends of the Fall (1994),Drama|Romance|War|Western
# ['266', 'Legends of the Fall (1994)', 'Drama|Romance|War|Wester']
# 267,Major Payne (1995),Comedy
# ['267', 'Major Payne (1995)', 'Comed']
# 269,My Crazy Life (Mi vida loca) (1993),Drama
# ['269', 'My Crazy Life (Mi vida loca) (1993)', 'Dram']
# 270,Love Affair (1994),Drama|Romance
# ['270', 'Love Affair (1994)', 'Drama|Romanc']
# 271,Losing Isaiah (1995),Drama
# ['271', 'Losing Isaiah (1995)', 'Dram']
# 272,"Madness of King George, The (1994)",Comedy|Drama
# ['272', '"Madness of King George', ' The (1994)"', 'Comedy|Dram']
# 273,Mary Shelley's Frankenstein (Frankenstein) (1994),Drama|Horror|Sci-Fi
# ['273', "Mary Shelley's Frankenstein (Frankenstein) (1994)", 'Drama|Horror|Sci-F']
# 274,Man of the House (1995),Comedy
# ['274', 'Man of the House (1995)', 'Comed']
# 275,Mixed Nuts (1994),Comedy
# ['275', 'Mixed Nuts (1994)', 'Comed']
# 276,Milk Money (1994),Comedy|Romance
# ['276', 'Milk Money (1994)', 'Comedy|Romanc']
# 277,Miracle on 34th Street (1994),Drama
# ['277', 'Miracle on 34th Street (1994)', 'Dram']
# 278,Miami Rhapsody (1995),Comedy
# ['278', 'Miami Rhapsody (1995)', 'Comed']
# 279,My Family (1995),Drama
# ['279', 'My Family (1995)', 'Dram']
# 280,Murder in the First (1995),Drama|Thriller
# ['280', 'Murder in the First (1995)', 'Drama|Thrille']
# 281,Nobody's Fool (1994),Comedy|Drama|Romance
# ['281', "Nobody's Fool (1994)", 'Comedy|Drama|Romanc']
# 282,Nell (1994),Drama
# ['282', 'Nell (1994)', 'Dram']
# 283,New Jersey Drive (1995),Crime|Drama
# ['283', 'New Jersey Drive (1995)', 'Crime|Dram']
# 284,New York Cop (NyÃ» YÃ´ku no koppu) (1993),Action|Crime
# ['284', 'New York Cop (NyÃ» YÃ´ku no koppu) (1993)', 'Action|Crim']
# 285,Beyond Bedlam (1993),Drama|Horror
# ['285', 'Beyond Bedlam (1993)', 'Drama|Horro']
# 287,Nina Takes a Lover (1994),Comedy|Romance
# ['287', 'Nina Takes a Lover (1994)', 'Comedy|Romanc']
# 288,Natural Born Killers (1994),Action|Crime|Thriller
# ['288', 'Natural Born Killers (1994)', 'Action|Crime|Thrille']
# 289,Only You (1994),Comedy|Romance
# ['289', 'Only You (1994)', 'Comedy|Romanc']
# 290,Once Were Warriors (1994),Crime|Drama
# ['290', 'Once Were Warriors (1994)', 'Crime|Dram']
# 291,Poison Ivy II (1996),Drama|Thriller
# ['291', 'Poison Ivy II (1996)', 'Drama|Thrille']
# 292,Outbreak (1995),Action|Drama|Sci-Fi|Thriller
# ['292', 'Outbreak (1995)', 'Action|Drama|Sci-Fi|Thrille']
# 293,LÃ©on: The Professional (a.k.a. The Professional) (LÃ©on) (1994),Action|Crime|Drama|Thriller
# ['293', 'LÃ©on: The Professional (a.k.a. The Professional) (LÃ©on) (1994)', 'Action|Crime|Drama|Thrille']
# 294,"Perez Family, The (1995)",Comedy|Romance
# ['294', '"Perez Family', ' The (1995)"', 'Comedy|Romanc']
# 295,"Pyromaniac's Love Story, A (1995)",Comedy|Romance
# ['295', '"Pyromaniac\'s Love Story', ' A (1995)"', 'Comedy|Romanc']
# 296,Pulp Fiction (1994),Comedy|Crime|Drama|Thriller
# ['296', 'Pulp Fiction (1994)', 'Comedy|Crime|Drama|Thrille']
# 298,Pushing Hands (Tui shou) (1992),Drama
# ['298', 'Pushing Hands (Tui shou) (1992)', 'Dram']
# 299,Priest (1994),Drama
# ['299', 'Priest (1994)', 'Dram']
# 300,Quiz Show (1994),Drama
# ['300', 'Quiz Show (1994)', 'Dram']
# 301,Picture Bride (Bijo photo) (1994),Drama|Romance
# ['301', 'Picture Bride (Bijo photo) (1994)', 'Drama|Romanc']
# 302,"Queen Margot (Reine Margot, La) (1994)",Drama|Romance
# ['302', '"Queen Margot (Reine Margot', ' La) (1994)"', 'Drama|Romanc']
# 303,"Quick and the Dead, The (1995)",Action|Thriller|Western
# ['303', '"Quick and the Dead', ' The (1995)"', 'Action|Thriller|Wester']
# 304,Roommates (1995),Comedy|Drama
# ['304', 'Roommates (1995)', 'Comedy|Dram']
# 305,Ready to Wear (Pret-A-Porter) (1994),Comedy
# ['305', 'Ready to Wear (Pret-A-Porter) (1994)', 'Comed']
# 306,Three Colors: Red (Trois couleurs: Rouge) (1994),Drama
# ['306', 'Three Colors: Red (Trois couleurs: Rouge) (1994)', 'Dram']
# 307,Three Colors: Blue (Trois couleurs: Bleu) (1993),Drama
# ['307', 'Three Colors: Blue (Trois couleurs: Bleu) (1993)', 'Dram']
# 308,Three Colors: White (Trzy kolory: Bialy) (1994),Comedy|Drama
# ['308', 'Three Colors: White (Trzy kolory: Bialy) (1994)', 'Comedy|Dram']
# 310,Rent-a-Kid (1995),Comedy
# ['310', 'Rent-a-Kid (1995)', 'Comed']
# 311,Relative Fear (1994),Horror|Thriller
# ['311', 'Relative Fear (1994)', 'Horror|Thrille']
# 312,Stuart Saves His Family (1995),Comedy
# ['312', 'Stuart Saves His Family (1995)', 'Comed']
# 313,"Swan Princess, The (1994)",Animation|Children
# ['313', '"Swan Princess', ' The (1994)"', 'Animation|Childre']
# 314,"Secret of Roan Inish, The (1994)",Children|Drama|Fantasy|Mystery
# ['314', '"Secret of Roan Inish', ' The (1994)"', 'Children|Drama|Fantasy|Myster']
# 315,"Specialist, The (1994)",Action|Drama|Thriller
# ['315', '"Specialist', ' The (1994)"', 'Action|Drama|Thrille']
# 316,Stargate (1994),Action|Adventure|Sci-Fi
# ['316', 'Stargate (1994)', 'Action|Adventure|Sci-F']
# 317,"Santa Clause, The (1994)",Comedy|Drama|Fantasy
# ['317', '"Santa Clause', ' The (1994)"', 'Comedy|Drama|Fantas']
# 318,"Shawshank Redemption, The (1994)",Crime|Drama
# ['318', '"Shawshank Redemption', ' The (1994)"', 'Crime|Dram']
# 319,Shallow Grave (1994),Comedy|Drama|Thriller
# ['319', 'Shallow Grave (1994)', 'Comedy|Drama|Thrille']
# 320,Suture (1993),Film-Noir|Thriller
# ['320', 'Suture (1993)', 'Film-Noir|Thrille']
# 321,Strawberry and Chocolate (Fresa y chocolate) (1993),Drama
# ['321', 'Strawberry and Chocolate (Fresa y chocolate) (1993)', 'Dram']
# 322,Swimming with Sharks (1995),Comedy|Drama
# ['322', 'Swimming with Sharks (1995)', 'Comedy|Dram']
# 324,"Sum of Us, The (1994)",Comedy|Drama
# ['324', '"Sum of Us', ' The (1994)"', 'Comedy|Dram']
# 325,National Lampoon's Senior Trip (1995),Comedy
# ['325', "National Lampoon's Senior Trip (1995)", 'Comed']
# 326,To Live (Huozhe) (1994),Drama
# ['326', 'To Live (Huozhe) (1994)', 'Dram']
# 327,Tank Girl (1995),Action|Comedy|Sci-Fi
# ['327', 'Tank Girl (1995)', 'Action|Comedy|Sci-F']
# 328,Tales from the Crypt Presents: Demon Knight (1995),Horror|Thriller
# ['328', 'Tales from the Crypt Presents: Demon Knight (1995)', 'Horror|Thrille']
# 329,Star Trek: Generations (1994),Adventure|Drama|Sci-Fi
# ['329', 'Star Trek: Generations (1994)', 'Adventure|Drama|Sci-F']
# 330,Tales from the Hood (1995),Action|Crime|Horror
# ['330', 'Tales from the Hood (1995)', 'Action|Crime|Horro']
# 331,Tom & Viv (1994),Drama
# ['331', 'Tom & Viv (1994)', 'Dram']
# 332,Village of the Damned (1995),Horror|Sci-Fi
# ['332', 'Village of the Damned (1995)', 'Horror|Sci-F']
# 333,Tommy Boy (1995),Comedy
# ['333', 'Tommy Boy (1995)', 'Comed']
# 334,Vanya on 42nd Street (1994),Drama
# ['334', 'Vanya on 42nd Street (1994)', 'Dram']
# 335,Underneath (1995),Mystery|Thriller
# ['335', 'Underneath (1995)', 'Mystery|Thrille']
# 336,"Walking Dead, The (1995)",Drama|War
# ['336', '"Walking Dead', ' The (1995)"', 'Drama|Wa']
# 337,What's Eating Gilbert Grape (1993),Drama
# ['337', "What's Eating Gilbert Grape (1993)", 'Dram']
# 338,Virtuosity (1995),Action|Sci-Fi|Thriller
# ['338', 'Virtuosity (1995)', 'Action|Sci-Fi|Thrille']
# 339,While You Were Sleeping (1995),Comedy|Romance
# ['339', 'While You Were Sleeping (1995)', 'Comedy|Romanc']
# 340,"War, The (1994)",Adventure|Drama|War
# ['340', '"War', ' The (1994)"', 'Adventure|Drama|Wa']
# 341,Double Happiness (1994),Drama
# ['341', 'Double Happiness (1994)', 'Dram']
# 342,Muriel's Wedding (1994),Comedy
# ['342', "Muriel's Wedding (1994)", 'Comed']
# 343,"Baby-Sitters Club, The (1995)",Children
# ['343', '"Baby-Sitters Club', ' The (1995)"', 'Childre']
# 344,Ace Ventura: Pet Detective (1994),Comedy
# ['344', 'Ace Ventura: Pet Detective (1994)', 'Comed']
# 345,"Adventures of Priscilla, Queen of the Desert, The (1994)",Comedy|Drama
# ['345', '"Adventures of Priscilla', ' Queen of the Desert', ' The (1994)"', 'Comedy|Dram']
# 346,Backbeat (1993),Drama|Musical
# ['346', 'Backbeat (1993)', 'Drama|Musica']
# 347,Bitter Moon (1992),Drama|Film-Noir|Romance
# ['347', 'Bitter Moon (1992)', 'Drama|Film-Noir|Romanc']
# 348,Bullets Over Broadway (1994),Comedy
# ['348', 'Bullets Over Broadway (1994)', 'Comed']
# 349,Clear and Present Danger (1994),Action|Crime|Drama|Thriller
# ['349', 'Clear and Present Danger (1994)', 'Action|Crime|Drama|Thrille']
# 350,"Client, The (1994)",Drama|Mystery|Thriller
# ['350', '"Client', ' The (1994)"', 'Drama|Mystery|Thrille']
# 351,"Corrina, Corrina (1994)",Comedy|Drama|Romance
# ['351', '"Corrina', ' Corrina (1994)"', 'Comedy|Drama|Romanc']
# 352,Crooklyn (1994),Comedy|Drama
# ['352', 'Crooklyn (1994)', 'Comedy|Dram']
# 353,"Crow, The (1994)",Action|Crime|Fantasy|Thriller
# ['353', '"Crow', ' The (1994)"', 'Action|Crime|Fantasy|Thrille']
# 354,Cobb (1994),Drama
# ['354', 'Cobb (1994)', 'Dram']
# 355,"Flintstones, The (1994)",Children|Comedy|Fantasy
# ['355', '"Flintstones', ' The (1994)"', 'Children|Comedy|Fantas']
# 356,Forrest Gump (1994),Comedy|Drama|Romance|War
# ['356', 'Forrest Gump (1994)', 'Comedy|Drama|Romance|Wa']
# 357,Four Weddings and a Funeral (1994),Comedy|Romance
# ['357', 'Four Weddings and a Funeral (1994)', 'Comedy|Romanc']
# 358,Higher Learning (1995),Drama
# ['358', 'Higher Learning (1995)', 'Dram']
# 359,I Like It Like That (1994),Comedy|Drama|Romance
# ['359', 'I Like It Like That (1994)', 'Comedy|Drama|Romanc']
# 360,I Love Trouble (1994),Action|Comedy
# ['360', 'I Love Trouble (1994)', 'Action|Comed']
# 361,It Could Happen to You (1994),Comedy|Drama|Romance
# ['361', 'It Could Happen to You (1994)', 'Comedy|Drama|Romanc']
# 362,"Jungle Book, The (1994)",Adventure|Children|Romance
# ['362', '"Jungle Book', ' The (1994)"', 'Adventure|Children|Romanc']
# 363,"Wonderful, Horrible Life of Leni Riefenstahl, The (Macht der Bilder: Leni Riefenstahl, Die) (1993)",Documentary
# ['363', '"Wonderful', ' Horrible Life of Leni Riefenstahl', ' The (Macht der Bilder: Leni Riefenstahl', ' Die) (1993)"', 'Documentar']
# 364,"Lion King, The (1994)",Adventure|Animation|Children|Drama|Musical|IMAX
# ['364', '"Lion King', ' The (1994)"', 'Adventure|Animation|Children|Drama|Musical|IMA']
# 365,Little Buddha (1993),Drama
# ['365', 'Little Buddha (1993)', 'Dram']
# 366,"Wes Craven's New Nightmare (Nightmare on Elm Street Part 7: Freddy's Finale, A) (1994)",Drama|Horror|Mystery|Thriller
# ['366', '"Wes Craven\'s New Nightmare (Nightmare on Elm Street Part 7: Freddy\'s Finale', ' A) (1994)"', 'Drama|Horror|Mystery|Thrille']
# 367,"Mask, The (1994)",Action|Comedy|Crime|Fantasy
# ['367', '"Mask', ' The (1994)"', 'Action|Comedy|Crime|Fantas']
# 368,Maverick (1994),Adventure|Comedy|Western
# ['368', 'Maverick (1994)', 'Adventure|Comedy|Wester']
# 369,Mrs. Parker and the Vicious Circle (1994),Drama
# ['369', 'Mrs. Parker and the Vicious Circle (1994)', 'Dram']
# 370,Naked Gun 33 1/3: The Final Insult (1994),Action|Comedy
# ['370', 'Naked Gun 33 1/3: The Final Insult (1994)', 'Action|Comed']
# 371,"Paper, The (1994)",Comedy|Drama
# ['371', '"Paper', ' The (1994)"', 'Comedy|Dram']
# 372,Reality Bites (1994),Comedy|Drama|Romance
# ['372', 'Reality Bites (1994)', 'Comedy|Drama|Romanc']
# 373,Red Rock West (1992),Thriller
# ['373', 'Red Rock West (1992)', 'Thrille']
# 374,Richie Rich (1994),Children|Comedy
# ['374', 'Richie Rich (1994)', 'Children|Comed']
# 376,"River Wild, The (1994)",Action|Thriller
# ['376', '"River Wild', ' The (1994)"', 'Action|Thrille']
# 377,Speed (1994),Action|Romance|Thriller
# ['377', 'Speed (1994)', 'Action|Romance|Thrille']
# 378,Speechless (1994),Comedy|Romance
# ['378', 'Speechless (1994)', 'Comedy|Romanc']
# 379,Timecop (1994),Action|Sci-Fi|Thriller
# ['379', 'Timecop (1994)', 'Action|Sci-Fi|Thrille']
# 380,True Lies (1994),Action|Adventure|Comedy|Romance|Thriller
# ['380', 'True Lies (1994)', 'Action|Adventure|Comedy|Romance|Thrille']
# 381,When a Man Loves a Woman (1994),Drama|Romance
# ['381', 'When a Man Loves a Woman (1994)', 'Drama|Romanc']
# 382,Wolf (1994),Drama|Horror|Romance|Thriller
# ['382', 'Wolf (1994)', 'Drama|Horror|Romance|Thrille']
# 383,Wyatt Earp (1994),Western
# ['383', 'Wyatt Earp (1994)', 'Wester']
# 384,Bad Company (1995),Action|Crime|Drama
# ['384', 'Bad Company (1995)', 'Action|Crime|Dram']
# 385,"Man of No Importance, A (1994)",Drama
# ['385', '"Man of No Importance', ' A (1994)"', 'Dram']
# 386,S.F.W. (1994),Drama
# ['386', 'S.F.W. (1994)', 'Dram']
# 387,"Low Down Dirty Shame, A (1994)",Action|Comedy
# ['387', '"Low Down Dirty Shame', ' A (1994)"', 'Action|Comed']
# 388,Boys Life (1995),Drama
# ['388', 'Boys Life (1995)', 'Dram']
# 389,"Colonel Chabert, Le (1994)",Drama|Romance|War
# ['389', '"Colonel Chabert', ' Le (1994)"', 'Drama|Romance|Wa']
# 390,Faster Pussycat! Kill! Kill! (1965),Action|Crime|Drama
# ['390', 'Faster Pussycat! Kill! Kill! (1965)', 'Action|Crime|Dram']
# 391,Jason's Lyric (1994),Crime|Drama
# ['391', "Jason's Lyric (1994)", 'Crime|Dram']
# 393,Street Fighter (1994),Action|Adventure|Fantasy
# ['393', 'Street Fighter (1994)', 'Action|Adventure|Fantas']
# 405,Highlander III: The Sorcerer (a.k.a. Highlander: The Final Dimension) (1994),Action|Fantasy
# ['405', 'Highlander III: The Sorcerer (a.k.a. Highlander: The Final Dimension) (1994)', 'Action|Fantas']
# 406,Federal Hill (1994),Drama
# ['406', 'Federal Hill (1994)', 'Dram']
# 407,In the Mouth of Madness (1995),Horror|Thriller
# ['407', 'In the Mouth of Madness (1995)', 'Horror|Thrille']
# 408,8 Seconds (1994),Drama
# ['408', '8 Seconds (1994)', 'Dram']
# 409,Above the Rim (1994),Crime|Drama
# ['409', 'Above the Rim (1994)', 'Crime|Dram']
# 410,Addams Family Values (1993),Children|Comedy|Fantasy
# ['410', 'Addams Family Values (1993)', 'Children|Comedy|Fantas']
# 412,"Age of Innocence, The (1993)",Drama
# ['412', '"Age of Innocence', ' The (1993)"', 'Dram']
# 413,Airheads (1994),Comedy
# ['413', 'Airheads (1994)', 'Comed']
# 414,"Air Up There, The (1994)",Comedy
# ['414', '"Air Up There', ' The (1994)"', 'Comed']
# 415,Another Stakeout (1993),Comedy|Thriller
# ['415', 'Another Stakeout (1993)', 'Comedy|Thrille']
# 416,Bad Girls (1994),Western
# ['416', 'Bad Girls (1994)', 'Wester']
# 417,Barcelona (1994),Comedy|Romance
# ['417', 'Barcelona (1994)', 'Comedy|Romanc']
# 418,Being Human (1993),Drama
# ['418', 'Being Human (1993)', 'Dram']
# 419,"Beverly Hillbillies, The (1993)",Comedy
# ['419', '"Beverly Hillbillies', ' The (1993)"', 'Comed']
# 420,Beverly Hills Cop III (1994),Action|Comedy|Crime|Thriller
# ['420', 'Beverly Hills Cop III (1994)', 'Action|Comedy|Crime|Thrille']
# 421,Black Beauty (1994),Adventure|Children|Drama
# ['421', 'Black Beauty (1994)', 'Adventure|Children|Dram']
# 422,Blink (1994),Thriller
# ['422', 'Blink (1994)', 'Thrille']
# 423,Blown Away (1994),Action|Thriller
# ['423', 'Blown Away (1994)', 'Action|Thrille']
# 424,Blue Chips (1994),Drama
# ['424', 'Blue Chips (1994)', 'Dram']
# 425,Blue Sky (1994),Drama|Romance
# ['425', 'Blue Sky (1994)', 'Drama|Romanc']
# 426,Body Snatchers (1993),Horror|Sci-Fi|Thriller
# ['426', 'Body Snatchers (1993)', 'Horror|Sci-Fi|Thrille']
# 427,Boxing Helena (1993),Drama|Mystery|Romance|Thriller
# ['427', 'Boxing Helena (1993)', 'Drama|Mystery|Romance|Thrille']
# 428,"Bronx Tale, A (1993)",Drama
# ['428', '"Bronx Tale', ' A (1993)"', 'Dram']
# 429,Cabin Boy (1994),Comedy
# ['429', 'Cabin Boy (1994)', 'Comed']
# 430,Calendar Girl (1993),Comedy|Drama
# ['430', 'Calendar Girl (1993)', 'Comedy|Dram']
# 431,Carlito's Way (1993),Crime|Drama
# ['431', "Carlito's Way (1993)", 'Crime|Dram']
# 432,City Slickers II: The Legend of Curly's Gold (1994),Adventure|Comedy|Western
# ['432', "City Slickers II: The Legend of Curly's Gold (1994)", 'Adventure|Comedy|Wester']
# 433,Clean Slate (1994),Comedy
# ['433', 'Clean Slate (1994)', 'Comed']
# 434,Cliffhanger (1993),Action|Adventure|Thriller
# ['434', 'Cliffhanger (1993)', 'Action|Adventure|Thrille']
# 435,Coneheads (1993),Comedy|Sci-Fi
# ['435', 'Coneheads (1993)', 'Comedy|Sci-F']
# 436,Color of Night (1994),Drama|Thriller
# ['436', 'Color of Night (1994)', 'Drama|Thrille']
# 437,Cops and Robbersons (1994),Comedy
# ['437', 'Cops and Robbersons (1994)', 'Comed']
# 438,"Cowboy Way, The (1994)",Action|Comedy|Drama
# ['438', '"Cowboy Way', ' The (1994)"', 'Action|Comedy|Dram']
# 440,Dave (1993),Comedy|Romance
# ['440', 'Dave (1993)', 'Comedy|Romanc']
# 441,Dazed and Confused (1993),Comedy
# ['441', 'Dazed and Confused (1993)', 'Comed']
# 442,Demolition Man (1993),Action|Adventure|Sci-Fi
# ['442', 'Demolition Man (1993)', 'Action|Adventure|Sci-F']
# 444,Even Cowgirls Get the Blues (1993),Comedy|Romance
# ['444', 'Even Cowgirls Get the Blues (1993)', 'Comedy|Romanc']
# 445,Fatal Instinct (1993),Comedy
# ['445', 'Fatal Instinct (1993)', 'Comed']
# 446,Farewell My Concubine (Ba wang bie ji) (1993),Drama|Romance
# ['446', 'Farewell My Concubine (Ba wang bie ji) (1993)', 'Drama|Romanc']
# 448,Fearless (1993),Drama
# ['448', 'Fearless (1993)', 'Dram']
# 449,Fear of a Black Hat (1994),Comedy
# ['449', 'Fear of a Black Hat (1994)', 'Comed']
# 450,With Honors (1994),Comedy|Drama
# ['450', 'With Honors (1994)', 'Comedy|Dram']
# 451,Flesh and Bone (1993),Drama|Mystery|Romance
# ['451', 'Flesh and Bone (1993)', 'Drama|Mystery|Romanc']
# 452,Widows' Peak (1994),Drama
# ['452', "Widows' Peak (1994)", 'Dram']
# 453,For Love or Money (1993),Comedy|Romance
# ['453', 'For Love or Money (1993)', 'Comedy|Romanc']
# 454,"Firm, The (1993)",Drama|Thriller
# ['454', '"Firm', ' The (1993)"', 'Drama|Thrille']
# 455,Free Willy (1993),Adventure|Children|Drama
# ['455', 'Free Willy (1993)', 'Adventure|Children|Dram']
# 456,Fresh (1994),Crime|Drama|Thriller
# ['456', 'Fresh (1994)', 'Crime|Drama|Thrille']
# 457,"Fugitive, The (1993)",Thriller
# ['457', '"Fugitive', ' The (1993)"', 'Thrille']
# 458,Geronimo: An American Legend (1993),Drama|Western
# ['458', 'Geronimo: An American Legend (1993)', 'Drama|Wester']
# 459,"Getaway, The (1994)",Action|Adventure|Crime|Drama|Romance|Thriller
# ['459', '"Getaway', ' The (1994)"', 'Action|Adventure|Crime|Drama|Romance|Thrille']
# 460,Getting Even with Dad (1994),Comedy
# ['460', 'Getting Even with Dad (1994)', 'Comed']
# 461,Go Fish (1994),Drama|Romance
# ['461', 'Go Fish (1994)', 'Drama|Romanc']
# 464,Hard Target (1993),Action|Adventure|Crime|Thriller
# ['464', 'Hard Target (1993)', 'Action|Adventure|Crime|Thrille']
# 466,Hot Shots! Part Deux (1993),Action|Comedy|War
# ['466', 'Hot Shots! Part Deux (1993)', 'Action|Comedy|Wa']
# 467,Live Nude Girls (1995),Comedy
# ['467', 'Live Nude Girls (1995)', 'Comed']
# 468,"Englishman Who Went Up a Hill But Came Down a Mountain, The (1995)",Comedy|Romance
# ['468', '"Englishman Who Went Up a Hill But Came Down a Mountain', ' The (1995)"', 'Comedy|Romanc']
# 469,"House of the Spirits, The (1993)",Drama|Romance
# ['469', '"House of the Spirits', ' The (1993)"', 'Drama|Romanc']
# 470,House Party 3 (1994),Comedy
# ['470', 'House Party 3 (1994)', 'Comed']
# 471,"Hudsucker Proxy, The (1994)",Comedy
# ['471', '"Hudsucker Proxy', ' The (1994)"', 'Comed']
# 472,I'll Do Anything (1994),Comedy|Drama
# ['472', "I'll Do Anything (1994)", 'Comedy|Dram']
# 473,In the Army Now (1994),Comedy|War
# ['473', 'In the Army Now (1994)', 'Comedy|Wa']
# 474,In the Line of Fire (1993),Action|Thriller
# ['474', 'In the Line of Fire (1993)', 'Action|Thrille']
# 475,In the Name of the Father (1993),Drama
# ['475', 'In the Name of the Father (1993)', 'Dram']
# 476,"Inkwell, The (1994)",Comedy|Drama
# ['476', '"Inkwell', ' The (1994)"', 'Comedy|Dram']
# 477,What's Love Got to Do with It? (1993),Drama|Musical
# ['477', "What's Love Got to Do with It? (1993)", 'Drama|Musica']
# 478,Jimmy Hollywood (1994),Comedy|Crime|Drama
# ['478', 'Jimmy Hollywood (1994)', 'Comedy|Crime|Dram']
# 479,Judgment Night (1993),Action|Crime|Thriller
# ['479', 'Judgment Night (1993)', 'Action|Crime|Thrille']
# 480,Jurassic Park (1993),Action|Adventure|Sci-Fi|Thriller
# ['480', 'Jurassic Park (1993)', 'Action|Adventure|Sci-Fi|Thrille']
# 481,Kalifornia (1993),Drama|Thriller
# ['481', 'Kalifornia (1993)', 'Drama|Thrille']
# 482,Killing Zoe (1994),Crime|Drama|Thriller
# ['482', 'Killing Zoe (1994)', 'Crime|Drama|Thrille']
# 484,Lassie (1994),Adventure|Children
# ['484', 'Lassie (1994)', 'Adventure|Childre']
# 485,Last Action Hero (1993),Action|Adventure|Comedy|Fantasy
# ['485', 'Last Action Hero (1993)', 'Action|Adventure|Comedy|Fantas']
# 486,Life with Mikey (1993),Comedy
# ['486', 'Life with Mikey (1993)', 'Comed']
# 487,Lightning Jack (1994),Comedy|Western
# ['487', 'Lightning Jack (1994)', 'Comedy|Wester']
# 488,M. Butterfly (1993),Drama|Romance
# ['488', 'M. Butterfly (1993)', 'Drama|Romanc']
# 489,Made in America (1993),Comedy
# ['489', 'Made in America (1993)', 'Comed']
# 490,Malice (1993),Thriller
# ['490', 'Malice (1993)', 'Thrille']
# 491,"Man Without a Face, The (1993)",Drama
# ['491', '"Man Without a Face', ' The (1993)"', 'Dram']
# 492,Manhattan Murder Mystery (1993),Comedy|Mystery
# ['492', 'Manhattan Murder Mystery (1993)', 'Comedy|Myster']
# 493,Menace II Society (1993),Action|Crime|Drama
# ['493', 'Menace II Society (1993)', 'Action|Crime|Dram']
# 494,Executive Decision (1996),Action|Adventure|Thriller
# ['494', 'Executive Decision (1996)', 'Action|Adventure|Thrille']
# 495,In the Realm of the Senses (Ai no corrida) (1976),Drama
# ['495', 'In the Realm of the Senses (Ai no corrida) (1976)', 'Dram']
# 496,What Happened Was... (1994),Comedy|Drama|Romance|Thriller
# ['496', 'What Happened Was... (1994)', 'Comedy|Drama|Romance|Thrille']
# 497,Much Ado About Nothing (1993),Comedy|Romance
# ['497', 'Much Ado About Nothing (1993)', 'Comedy|Romanc']
# 499,Mr. Wonderful (1993),Comedy|Romance
# ['499', 'Mr. Wonderful (1993)', 'Comedy|Romanc']
# 500,Mrs. Doubtfire (1993),Comedy|Drama
# ['500', 'Mrs. Doubtfire (1993)', 'Comedy|Dram']
# 501,Naked (1993),Drama
# ['501', 'Naked (1993)', 'Dram']
# 502,"Next Karate Kid, The (1994)",Action|Children|Romance
# ['502', '"Next Karate Kid', ' The (1994)"', 'Action|Children|Romanc']
# 504,No Escape (1994),Action|Drama|Sci-Fi
# ['504', 'No Escape (1994)', 'Action|Drama|Sci-F']
# 505,North (1994),Comedy
# ['505', 'North (1994)', 'Comed']
# 506,Orlando (1992),Drama|Fantasy|Romance
# ['506', 'Orlando (1992)', 'Drama|Fantasy|Romanc']
# 507,"Perfect World, A (1993)",Crime|Drama|Thriller
# ['507', '"Perfect World', ' A (1993)"', 'Crime|Drama|Thrille']
# 508,Philadelphia (1993),Drama
# ['508', 'Philadelphia (1993)', 'Dram']
# 509,"Piano, The (1993)",Drama|Romance
# ['509', '"Piano', ' The (1993)"', 'Drama|Romanc']
# 510,Poetic Justice (1993),Drama
# ['510', 'Poetic Justice (1993)', 'Dram']
# 511,"Program, The (1993)",Action|Drama
# ['511', '"Program', ' The (1993)"', 'Action|Dram']
# 512,"Puppet Masters, The (1994)",Horror|Sci-Fi
# ['512', '"Puppet Masters', ' The (1994)"', 'Horror|Sci-F']
# 513,Radioland Murders (1994),Comedy|Mystery|Romance
# ['513', 'Radioland Murders (1994)', 'Comedy|Mystery|Romanc']
# 514,"Ref, The (1994)",Comedy
# ['514', '"Ref', ' The (1994)"', 'Comed']
# 515,"Remains of the Day, The (1993)",Drama|Romance
# ['515', '"Remains of the Day', ' The (1993)"', 'Drama|Romanc']
# 516,Renaissance Man (1994),Comedy|Drama
# ['516', 'Renaissance Man (1994)', 'Comedy|Dram']
# 517,Rising Sun (1993),Action|Drama|Mystery
# ['517', 'Rising Sun (1993)', 'Action|Drama|Myster']
# 518,"Road to Wellville, The (1994)",Comedy
# ['518', '"Road to Wellville', ' The (1994)"', 'Comed']
# 519,RoboCop 3 (1993),Action|Crime|Drama|Sci-Fi|Thriller
# ['519', 'RoboCop 3 (1993)', 'Action|Crime|Drama|Sci-Fi|Thrille']
# 520,Robin Hood: Men in Tights (1993),Comedy
# ['520', 'Robin Hood: Men in Tights (1993)', 'Comed']
# 521,Romeo Is Bleeding (1993),Crime|Thriller
# ['521', 'Romeo Is Bleeding (1993)', 'Crime|Thrille']
# 522,Romper Stomper (1992),Action|Drama
# ['522', 'Romper Stomper (1992)', 'Action|Dram']
# 523,Ruby in Paradise (1993),Drama
# ['523', 'Ruby in Paradise (1993)', 'Dram']
# 524,Rudy (1993),Drama
# ['524', 'Rudy (1993)', 'Dram']
# 526,"Savage Nights (Nuits fauves, Les) (1992)",Drama
# ['526', '"Savage Nights (Nuits fauves', ' Les) (1992)"', 'Dram']
# 527,Schindler's List (1993),Drama|War
# ['527', "Schindler's List (1993)", 'Drama|Wa']
# 528,"Scout, The (1994)",Comedy|Drama
# ['528', '"Scout', ' The (1994)"', 'Comedy|Dram']
# 529,Searching for Bobby Fischer (1993),Drama
# ['529', 'Searching for Bobby Fischer (1993)', 'Dram']
# 531,"Secret Garden, The (1993)",Children|Drama
# ['531', '"Secret Garden', ' The (1993)"', 'Children|Dram']
# 532,Serial Mom (1994),Comedy|Crime|Horror
# ['532', 'Serial Mom (1994)', 'Comedy|Crime|Horro']
# 533,"Shadow, The (1994)",Action|Adventure|Fantasy|Mystery
# ['533', '"Shadow', ' The (1994)"', 'Action|Adventure|Fantasy|Myster']
# 534,Shadowlands (1993),Drama|Romance
# ['534', 'Shadowlands (1993)', 'Drama|Romanc']
# 535,Short Cuts (1993),Drama
# ['535', 'Short Cuts (1993)', 'Dram']
# 536,"Simple Twist of Fate, A (1994)",Drama
# ['536', '"Simple Twist of Fate', ' A (1994)"', 'Dram']
# 537,Sirens (1994),Drama
# ['537', 'Sirens (1994)', 'Dram']
# 538,Six Degrees of Separation (1993),Drama
# ['538', 'Six Degrees of Separation (1993)', 'Dram']
# 539,Sleepless in Seattle (1993),Comedy|Drama|Romance
# ['539', 'Sleepless in Seattle (1993)', 'Comedy|Drama|Romanc']
# 540,Sliver (1993),Thriller
# ['540', 'Sliver (1993)', 'Thrille']
# 541,Blade Runner (1982),Action|Sci-Fi|Thriller
# ['541', 'Blade Runner (1982)', 'Action|Sci-Fi|Thrille']
# 542,Son in Law (1993),Comedy|Drama|Romance
# ['542', 'Son in Law (1993)', 'Comedy|Drama|Romanc']
# 543,So I Married an Axe Murderer (1993),Comedy|Romance|Thriller
# ['543', 'So I Married an Axe Murderer (1993)', 'Comedy|Romance|Thrille']
# 544,Striking Distance (1993),Action|Crime
# ['544', 'Striking Distance (1993)', 'Action|Crim']
# 546,Super Mario Bros. (1993),Action|Adventure|Children|Comedy|Fantasy|Sci-Fi
# ['546', 'Super Mario Bros. (1993)', 'Action|Adventure|Children|Comedy|Fantasy|Sci-F']
# 547,Surviving the Game (1994),Action|Adventure|Thriller
# ['547', 'Surviving the Game (1994)', 'Action|Adventure|Thrille']
# 548,Terminal Velocity (1994),Action|Mystery|Thriller
# ['548', 'Terminal Velocity (1994)', 'Action|Mystery|Thrille']
# 549,Thirty-Two Short Films About Glenn Gould (1993),Drama|Musical
# ['549', 'Thirty-Two Short Films About Glenn Gould (1993)', 'Drama|Musica']
# 550,Threesome (1994),Comedy|Romance
# ['550', 'Threesome (1994)', 'Comedy|Romanc']
# 551,"Nightmare Before Christmas, The (1993)",Animation|Children|Fantasy|Musical
# ['551', '"Nightmare Before Christmas', ' The (1993)"', 'Animation|Children|Fantasy|Musica']
# 552,"Three Musketeers, The (1993)",Action|Adventure|Comedy|Romance
# ['552', '"Three Musketeers', ' The (1993)"', 'Action|Adventure|Comedy|Romanc']
# 553,Tombstone (1993),Action|Drama|Western
# ['553', 'Tombstone (1993)', 'Action|Drama|Wester']
# 555,True Romance (1993),Crime|Thriller
# ['555', 'True Romance (1993)', 'Crime|Thrille']
# 556,"War Room, The (1993)",Documentary
# ['556', '"War Room', ' The (1993)"', 'Documentar']
# 558,"Pagemaster, The (1994)",Action|Adventure|Animation|Children|Fantasy
# ['558', '"Pagemaster', ' The (1994)"', 'Action|Adventure|Animation|Children|Fantas']
# 562,Welcome to the Dollhouse (1995),Comedy|Drama
# ['562', 'Welcome to the Dollhouse (1995)', 'Comedy|Dram']
# 563,Germinal (1993),Drama|Romance
# ['563', 'Germinal (1993)', 'Drama|Romanc']
# 564,Chasers (1994),Comedy
# ['564', 'Chasers (1994)', 'Comed']
# 567,Kika (1993),Comedy|Drama
# ['567', 'Kika (1993)', 'Comedy|Dram']
# 568,Bhaji on the Beach (1993),Comedy|Drama
# ['568', 'Bhaji on the Beach (1993)', 'Comedy|Dram']
# 569,Little Big League (1994),Comedy|Drama
# ['569', 'Little Big League (1994)', 'Comedy|Dram']
# 573,"Ciao, Professore! (Io speriamo che me la cavo) (1992)",Drama
# ['573', '"Ciao', ' Professore! (Io speriamo che me la cavo) (1992)"', 'Dram']
# 574,Spanking the Monkey (1994),Comedy|Drama
# ['574', 'Spanking the Monkey (1994)', 'Comedy|Dram']
# 575,"Little Rascals, The (1994)",Children|Comedy
# ['575', '"Little Rascals', ' The (1994)"', 'Children|Comed']
# 577,Andre (1994),Adventure|Children|Drama
# ['577', 'Andre (1994)', 'Adventure|Children|Dram']
# 579,"Escort, The (Scorta, La) (1993)",Crime|Thriller
# ['579', '"Escort', ' The (Scorta', ' La) (1993)"', 'Crime|Thrille']
# 580,Princess Caraboo (1994),Drama
# ['580', 'Princess Caraboo (1994)', 'Dram']
# 581,"Celluloid Closet, The (1995)",Documentary
# ['581', '"Celluloid Closet', ' The (1995)"', 'Documentar']
# 583,Dear Diary (Caro Diario) (1994),Comedy|Drama
# ['583', 'Dear Diary (Caro Diario) (1994)', 'Comedy|Dram']
# 585,"Brady Bunch Movie, The (1995)",Comedy
# ['585', '"Brady Bunch Movie', ' The (1995)"', 'Comed']
# 586,Home Alone (1990),Children|Comedy
# ['586', 'Home Alone (1990)', 'Children|Comed']
# 587,Ghost (1990),Comedy|Drama|Fantasy|Romance|Thriller
# ['587', 'Ghost (1990)', 'Comedy|Drama|Fantasy|Romance|Thrille']
# 588,Aladdin (1992),Adventure|Animation|Children|Comedy|Musical
# ['588', 'Aladdin (1992)', 'Adventure|Animation|Children|Comedy|Musica']
# 589,Terminator 2: Judgment Day (1991),Action|Sci-Fi
# ['589', 'Terminator 2: Judgment Day (1991)', 'Action|Sci-F']
# 590,Dances with Wolves (1990),Adventure|Drama|Western
# ['590', 'Dances with Wolves (1990)', 'Adventure|Drama|Wester']
# 592,Batman (1989),Action|Crime|Thriller
# ['592', 'Batman (1989)', 'Action|Crime|Thrille']
# 593,"Silence of the Lambs, The (1991)",Crime|Horror|Thriller
# ['593', '"Silence of the Lambs', ' The (1991)"', 'Crime|Horror|Thrille']
# 594,Snow White and the Seven Dwarfs (1937),Animation|Children|Drama|Fantasy|Musical
# ['594', 'Snow White and the Seven Dwarfs (1937)', 'Animation|Children|Drama|Fantasy|Musica']
# 595,Beauty and the Beast (1991),Animation|Children|Fantasy|Musical|Romance|IMAX
# ['595', 'Beauty and the Beast (1991)', 'Animation|Children|Fantasy|Musical|Romance|IMA']
# 596,Pinocchio (1940),Animation|Children|Fantasy|Musical
# ['596', 'Pinocchio (1940)', 'Animation|Children|Fantasy|Musica']
# 597,Pretty Woman (1990),Comedy|Romance
# ['597', 'Pretty Woman (1990)', 'Comedy|Romanc']
# 599,"Wild Bunch, The (1969)",Adventure|Western
# ['599', '"Wild Bunch', ' The (1969)"', 'Adventure|Wester']
# 600,Love and a .45 (1994),Action|Comedy|Crime
# ['600', 'Love and a .45 (1994)', 'Action|Comedy|Crim']
# 602,"Great Day in Harlem, A (1994)",Documentary
# ['602', '"Great Day in Harlem', ' A (1994)"', 'Documentar']
# 605,One Fine Day (1996),Drama|Romance
# ['605', 'One Fine Day (1996)', 'Drama|Romanc']
# 606,Candyman: Farewell to the Flesh (1995),Fantasy|Horror
# ['606', 'Candyman: Farewell to the Flesh (1995)', 'Fantasy|Horro']
# 608,Fargo (1996),Comedy|Crime|Drama|Thriller
# ['608', 'Fargo (1996)', 'Comedy|Crime|Drama|Thrille']
# 609,Homeward Bound II: Lost in San Francisco (1996),Adventure|Children
# ['609', 'Homeward Bound II: Lost in San Francisco (1996)', 'Adventure|Childre']
# 610,Heavy Metal (1981),Action|Adventure|Animation|Horror|Sci-Fi
# ['610', 'Heavy Metal (1981)', 'Action|Adventure|Animation|Horror|Sci-F']
# 611,Hellraiser: Bloodline (1996),Action|Horror|Sci-Fi
# ['611', 'Hellraiser: Bloodline (1996)', 'Action|Horror|Sci-F']
# 612,"Pallbearer, The (1996)",Comedy
# ['612', '"Pallbearer', ' The (1996)"', 'Comed']
# 613,Jane Eyre (1996),Drama|Romance
# ['613', 'Jane Eyre (1996)', 'Drama|Romanc']
# 615,Bread and Chocolate (Pane e cioccolata) (1973),Comedy|Drama
# ['615', 'Bread and Chocolate (Pane e cioccolata) (1973)', 'Comedy|Dram']
# 616,"Aristocats, The (1970)",Animation|Children
# ['616', '"Aristocats', ' The (1970)"', 'Animation|Childre']
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-9-d26f914a3b60> in <module>
# ----> 1 shingles, movieDict, movieDictInv  = get_shingle_hash(hash_size, movies_filename)
#       2 hash_coeffs = get_hash_coeffs(br)
#       3 M = min_hashing(shingles, hash_coeffs, br)
#       4 bucket_list = LSH(M, b, r, band_hash_size)
#
# <ipython-input-7-10597d5cd6f2> in get_shingle_hash(hash_size, filename)
#       7         next(f)
#       8         i = 0
# ----> 9         for line in f:
#      10             if line[-1] == '\n':
#      11                 line = line[0:-1]
#
# c:\users\mehak\appdata\local\programs\python\python36\lib\encodings\cp1252.py in decode(self, input, final)
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
#      22     def decode(self, input, final=False):
# ---> 23         return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#      24
#      25 class StreamWriter(Codec,codecs.StreamWriter):
#
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x81 in position 827: character maps to <undefined>

# %%
result = []
for index, row in ratings_test.iterrows():
    mlist = list(ratings_train.loc[ratings_train['userId'] == row['userId']]['movieId'])
    mrlist = list(ratings_train.loc[ratings_train['userId'] == row['userId']]['rating'])
    mlistSet = set(mlist)
    movieID = row['movieId']
    movieIDIdx = movieDict[movieID]
    meanRatingByUser = np.mean(mrlist)    
    sims, simsSet = find_similiar(shingles, movieIDIdx, threshold, bucket_list, M, b, r, band_hash_size, verify_by_signature, movieDictInv)
    
    intersection = mlistSet.intersection(simsSet)
    
    if len(intersection)==0:
        result.append(meanRatingByUser)
    
    else:
        ratingCommon = 0
        for i in range(len(mlist)):
            if mlist[i] in intersection:
                ratingCommon += (mrlist[i]*sims[mlist[i]])
                
        ratingCommon = ratingCommon/len(intersection)
        if ratingCommon < 1.0:
            ratingCommon = 1.0
        elif ratingCommon > 5.0:
            ratingCommon = 5.0
        result.append(ratingCommon)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-d941f0755781> in <module>
#       5     mlistSet = set(mlist)
#       6     movieID = row['movieId']
# ----> 7     movieIDIdx = movieDict[movieID]
#       8     meanRatingByUser = np.mean(mrlist)
#       9     sims, simsSet = find_similiar(shingles, movieIDIdx, threshold, bucket_list, M, b, r, band_hash_size, verify_by_signature, movieDictInv)
#
# NameError: name 'movieDict' is not defined

# %%
from sklearn.metrics import mean_squared_error

rmseError = np.sqrt(mean_squared_error(ratings_test_truth['rating'],result))

print(rmseError)
# Out:
# 1.0091969002719883

# %%
0.9968427290744207 7 , 2
0.9969012605414767 7,2, 0.84
1.0091969002719883
